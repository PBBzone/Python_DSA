# %%
list = [1,2,3,4,5]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
list = [5,2,1,4,3]
list.append(10)
print(list)

list.insert(1,20)
print(list)

list.sort()
print(list)
list.remove(4)
print(list)
# Out:
# [5, 2, 1, 4, 3, 10]
# [5, 20, 2, 1, 4, 3, 10]
# [1, 2, 3, 4, 5, 10, 20]
# [1, 2, 3, 5, 10, 20]

# %%
list =[1,2,2,2,3,4,5]
list.reverse()
print(list)
print(list.count(2))
list2 = ["a","b","c","d"]
print("index of c =",list2.index("c"))
# Out:
# [5, 4, 3, 2, 2, 2, 1]
# 3
# index of c = 2

# %%
number=[5,7,7,9,3,3,5,2,2,4]
rem=[]
for i in number:
    if i not in rem:
        rem.append(i)
print("actual list:",number)
print("after removing",rem)
# Out:
# actual list: [5, 7, 7, 9, 3, 3, 5, 2, 2, 4]
# after removing [5, 7, 9, 3, 2, 4]

# %%
num = [2,4,3,6,8,7,9]
target = 10
rem=[]
for i in range

# %%
num[1,1,1,2,2,2,3,4,4,5,5]
dic={}
for i
