# %%
number=int(input("enter any number:"))
count=0
while number>0:
    count+=1
    number//=10
print(count)
# Out:
# 4

# %%
number=int(input("enter any number:"))
if number%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %%
number=12
if number%2!=0:
    print("odd number")
else:
    print("even  number")
# Out:
# even  number

# %%
for i in range(1,21):
    if i%2==0:
        print(i,"  even")

print ("odd number")        
for i in range(1,21):
   if i % 2 !=0:
      print(i,"  odd")
# Out:
# 2   even
# 4   even
# 6   even
# 8   even
# 10   even
# 12   even
# 14   even
# 16   even
# 18   even
# 20   even
# odd number
# 1   odd
# 3   odd
# 5   odd
# 7   odd
# 9   odd
# 11   odd
# 13   odd
# 15   odd
# 17   odd
# 19   odd

# %%
num = 10
add = 0
for i in range(1,num+1):
    add=add+1
print ("addition =",add)
# Out:
# addition = 10

# %%
#find factorial number 4 5 7
number = 5
fact = 1
for i in range(1,number+1):
    fact = number *fact 
    print(fact)
# Out:
# 5
# 25
# 125
# 625
# 3125

# %%
def factorial(x):
    if x==0:
        return 0
    return x*factorial(x-1)

# %%
num1 = int(input("enter any number:"))
for i in range (1,11):
    print(num1,"x",i,"=",num1*i)

# %%
#count didgits in number
numb2 = int(input("enter some numbers:"))

# %%
num=10
add=0
for i in range(1,num+1):
    add=add+i
print("Addition = ",add)
# Out:
# Addition =  55

# %%
number = 12345
reverse = 0
while number>0:
    reverse=reverse*10+number%10
    number//=10
print(reverse)
